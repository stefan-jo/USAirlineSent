# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Back-translation with open source hugginface transformer models for NMT

# %%
from fastai2.text.all import *

# %%
from transformers import MarianMTModel, MarianTokenizer

# %%
path = Path('.')
path.ls()
# Out:
# (#20) [Path('Tweets_valid_translated.csv'),Path('training.1600000.processed.noemoticon.csv'),Path('tweets_ULMFit_QRNN_subword.ipynb'),Path('dls_lm.pkl'),Path('dls_lm_qrnn.pkl'),Path('Tweets_valid_full.csv'),Path('tweets_QRNN_Final.ipynb'),Path('.ipynb_checkpoints'),Path('tweets_Data-Aug.ipynb'),Path('tmp')...]

# %% [markdown]
# ## Data loading

# %%
df = pd.read_csv(path/'Tweets_valid.csv')

# %%
df['text'] = df['text'].apply(lambda x: x.replace('\n', ' '))

# %% [markdown]
# ## Back translation part 1: English-German-English

# %% [markdown]
# Define source and target language and model name

# %%
src = 'en'
trg = 'de'

# %%
mname = f'Helsinki-NLP/opus-mt-{src}-{trg}'

# %%
mname
# Out:
# 'Helsinki-NLP/opus-mt-en-de'

# %% [markdown]
# Download pretrained NMT model and the corresponding tokenizer from huggingface model hub

# %%
tokenizer = MarianTokenizer.from_pretrained(mname)
model = MarianMTModel.from_pretrained(mname)
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils.py:831: FutureWarning: Parameter max_len is deprecated and will be removed in a future release. Use model_max_length instead.
#   category=FutureWarning,

# %% [markdown]
# Put model on GPU to speed up inference

# %%
model.cuda();

# %% [markdown]
# Translation loop for translating from EN to DE:
# - loops through the dataset in batches of size 32
# - tokenizes the input texts
# - runs inference on the pre-trained NMT model
# - decodes the translated outputs from indices to words

# %%
bs = 32
translated = []
for i in range(int(len(df)/bs)+1):
    if len(df)-(i*bs)<=bs:
        print(f'Selecting reviews {i*bs} until {len(df)}')
        src_texts=df.loc[i*bs:,'text']
    else: 
        print(f'Selecting reviews {i*bs} until {i*bs+bs-1}')
        src_texts=df.loc[i*bs:i*bs+bs-1,'text']
    batch = tokenizer.prepare_translation_batch(src_texts=src_texts)
    batch
    print('translating...')
    gen = model.generate(batch.input_ids.cuda())
    print('decoding...')
    decoded = [tokenizer.decode(g, skip_special_tokens=True) for g in gen]
    translated.extend(decoded)
# Out:
# Selecting reviews 0 until 31
# translating...
# decoding...
# Selecting reviews 32 until 63
# translating...
# decoding...
# Selecting reviews 64 until 95
# translating...
# decoding...
# Selecting reviews 96 until 127
# translating...
# decoding...
# Selecting reviews 128 until 159
# translating...
# decoding...
# Selecting reviews 160 until 191
# translating...
# decoding...
# Selecting reviews 192 until 223
# translating...
# decoding...
# Selecting reviews 224 until 255
# translating...
# decoding...
# Selecting reviews 256 until 287
# translating...
# decoding...
# Selecting reviews 288 until 319
# translating...
# decoding...
# Selecting reviews 320 until 351
# translating...
# decoding...
# Selecting reviews 352 until 383
# translating...
# decoding...
# Selecting reviews 384 until 415
# translating...
# decoding...
# Selecting reviews 416 until 447
# translating...
# decoding...
# Selecting reviews 448 until 479
# translating...
# decoding...
# Selecting reviews 480 until 511
# translating...
# decoding...
# Selecting reviews 512 until 543
# translating...
# decoding...
# Selecting reviews 544 until 575
# translating...
# decoding...
# Selecting reviews 576 until 607
# translating...
# decoding...
# Selecting reviews 608 until 639
# translating...
# decoding...
# Selecting reviews 640 until 671
# translating...
# decoding...
# Selecting reviews 672 until 703
# translating...
# decoding...
# Selecting reviews 704 until 735
# translating...
# decoding...
# Selecting reviews 736 until 767
# translating...
# decoding...
# Selecting reviews 768 until 799
# translating...
# decoding...
# Selecting reviews 800 until 831
# translating...
# decoding...
# Selecting reviews 832 until 863
# translating...
# decoding...
# Selecting reviews 864 until 895
# translating...
# decoding...
# Selecting reviews 896 until 927
# translating...
# decoding...
# Selecting reviews 928 until 959
# translating...
# decoding...
# Selecting reviews 960 until 991
# translating...
# decoding...
# Selecting reviews 992 until 1023
# translating...
# decoding...
# Selecting reviews 1024 until 1055
# translating...
# decoding...
# Selecting reviews 1056 until 1087
# translating...
# decoding...
# Selecting reviews 1088 until 1119
# translating...
# decoding...
# Selecting reviews 1120 until 1151
# translating...
# decoding...
# Selecting reviews 1152 until 1183
# translating...
# decoding...
# Selecting reviews 1184 until 1215
# translating...
# decoding...
# Selecting reviews 1216 until 1247
# translating...
# decoding...
# Selecting reviews 1248 until 1279
# translating...
# decoding...
# Selecting reviews 1280 until 1311
# translating...
# decoding...
# Selecting reviews 1312 until 1343
# translating...
# decoding...
# Selecting reviews 1344 until 1375
# translating...
# decoding...
# Selecting reviews 1376 until 1407
# translating...
# decoding...
# Selecting reviews 1408 until 1439
# translating...
# decoding...
# Selecting reviews 1440 until 1471
# translating...
# decoding...
# Selecting reviews 1472 until 1503
# translating...
# decoding...
# Selecting reviews 1504 until 1535
# translating...
# decoding...
# Selecting reviews 1536 until 1567
# translating...
# decoding...
# Selecting reviews 1568 until 1599
# translating...
# decoding...
# Selecting reviews 1600 until 1631
# translating...
# decoding...
# Selecting reviews 1632 until 1663
# translating...
# decoding...
# Selecting reviews 1664 until 1695
# translating...
# decoding...
# Selecting reviews 1696 until 1727
# translating...
# decoding...
# Selecting reviews 1728 until 1759
# translating...
# decoding...
# Selecting reviews 1760 until 1791
# translating...
# decoding...
# Selecting reviews 1792 until 1823
# translating...
# decoding...
# Selecting reviews 1824 until 1855
# translating...
# decoding...
# Selecting reviews 1856 until 1887
# translating...
# decoding...
# Selecting reviews 1888 until 1919
# translating...
# decoding...
# Selecting reviews 1920 until 1951
# translating...
# decoding...
# Selecting reviews 1952 until 1983
# translating...
# decoding...
# Selecting reviews 1984 until 2015
# translating...
# decoding...
# Selecting reviews 2016 until 2047
# translating...
# decoding...
# Selecting reviews 2048 until 2079
# translating...
# decoding...
# Selecting reviews 2080 until 2111
# translating...
# decoding...
# Selecting reviews 2112 until 2143
# translating...
# decoding...
# Selecting reviews 2144 until 2175
# translating...
# decoding...
# Selecting reviews 2176 until 2207
# translating...
# decoding...
# Selecting reviews 2208 until 2239
# translating...
# decoding...
# Selecting reviews 2240 until 2271
# translating...
# decoding...
# Selecting reviews 2272 until 2303
# translating...
# decoding...
# Selecting reviews 2304 until 2335
# translating...
# decoding...
# Selecting reviews 2336 until 2367
# translating...
# decoding...
# Selecting reviews 2368 until 2399
# translating...
# decoding...
# Selecting reviews 2400 until 2431
# translating...
# decoding...
# Selecting reviews 2432 until 2463
# translating...
# decoding...
# Selecting reviews 2464 until 2495
# translating...
# decoding...
# Selecting reviews 2496 until 2527
# translating...
# decoding...
# Selecting reviews 2528 until 2559
# translating...
# decoding...
# Selecting reviews 2560 until 2591
# translating...
# decoding...
# Selecting reviews 2592 until 2623
# translating...
# decoding...
# Selecting reviews 2624 until 2655
# translating...
# decoding...
# Selecting reviews 2656 until 2687
# translating...
# decoding...
# Selecting reviews 2688 until 2719
# translating...
# decoding...
# Selecting reviews 2720 until 2751
# translating...
# decoding...
# Selecting reviews 2752 until 2783
# translating...
# decoding...
# Selecting reviews 2784 until 2815
# translating...
# decoding...
# Selecting reviews 2816 until 2847
# translating...
# decoding...
# Selecting reviews 2848 until 2879
# translating...
# decoding...
# Selecting reviews 2880 until 2911
# translating...
# decoding...
# Selecting reviews 2912 until 2943
# translating...
# decoding...
# Selecting reviews 2944 until 2975
# translating...
# decoding...
# Selecting reviews 2976 until 3007
# translating...
# decoding...
# Selecting reviews 3008 until 3039
# translating...
# decoding...
# Selecting reviews 3040 until 3071
# translating...
# decoding...
# Selecting reviews 3072 until 3103
# translating...
# decoding...
# Selecting reviews 3104 until 3135
# translating...
# decoding...
# Selecting reviews 3136 until 3167
# translating...
# decoding...
# Selecting reviews 3168 until 3199
# translating...
# decoding...
# Selecting reviews 3200 until 3231
# translating...
# decoding...
# Selecting reviews 3232 until 3263
# translating...
# decoding...
# Selecting reviews 3264 until 3295
# translating...
# decoding...
# Selecting reviews 3296 until 3327
# translating...
# decoding...
# Selecting reviews 3328 until 3359
# translating...
# decoding...
# Selecting reviews 3360 until 3391
# translating...
# decoding...
# Selecting reviews 3392 until 3423
# translating...
# decoding...
# Selecting reviews 3424 until 3455
# translating...
# decoding...
# Selecting reviews 3456 until 3487
# translating...
# decoding...
# Selecting reviews 3488 until 3519
# translating...
# decoding...
# Selecting reviews 3520 until 3551
# translating...
# decoding...
# Selecting reviews 3552 until 3583
# translating...
# decoding...
# Selecting reviews 3584 until 3615
# translating...
# decoding...
# Selecting reviews 3616 until 3647
# translating...
# decoding...
# Selecting reviews 3648 until 3679
# translating...
# decoding...
# Selecting reviews 3680 until 3711
# translating...
# decoding...
# Selecting reviews 3712 until 3743
# translating...
# decoding...
# Selecting reviews 3744 until 3775
# translating...
# decoding...
# Selecting reviews 3776 until 3807
# translating...
# decoding...
# Selecting reviews 3808 until 3839
# translating...
# decoding...
# Selecting reviews 3840 until 3871
# translating...
# decoding...
# Selecting reviews 3872 until 3903
# translating...
# decoding...
# Selecting reviews 3904 until 3935
# translating...
# decoding...
# Selecting reviews 3936 until 3967
# translating...
# decoding...
# Selecting reviews 3968 until 3999
# translating...
# decoding...
# Selecting reviews 4000 until 4031
# translating...
# decoding...
# Selecting reviews 4032 until 4063
# translating...
# decoding...
# Selecting reviews 4064 until 4095
# translating...
# decoding...
# Selecting reviews 4096 until 4127
# translating...
# decoding...
# Selecting reviews 4128 until 4159
# translating...
# decoding...
# Selecting reviews 4160 until 4191
# translating...
# decoding...
# Selecting reviews 4192 until 4223
# translating...
# decoding...
# Selecting reviews 4224 until 4255
# translating...
# decoding...
# Selecting reviews 4256 until 4287
# translating...
# decoding...
# Selecting reviews 4288 until 4319
# translating...
# decoding...
# Selecting reviews 4320 until 4351
# translating...
# decoding...
# Selecting reviews 4352 until 4383
# translating...
# decoding...
# Selecting reviews 4384 until 4415
# translating...
# decoding...
# Selecting reviews 4416 until 4447
# translating...
# decoding...
# Selecting reviews 4448 until 4479
# translating...
# decoding...
# Selecting reviews 4480 until 4511
# translating...
# decoding...
# Selecting reviews 4512 until 4543
# translating...
# decoding...
# Selecting reviews 4544 until 4575
# translating...
# decoding...
# Selecting reviews 4576 until 4607
# translating...
# decoding...
# Selecting reviews 4608 until 4639
# translating...
# decoding...
# Selecting reviews 4640 until 4671
# translating...
# decoding...
# Selecting reviews 4672 until 4703
# translating...
# decoding...
# Selecting reviews 4704 until 4735
# translating...
# decoding...
# Selecting reviews 4736 until 4767
# translating...
# decoding...
# Selecting reviews 4768 until 4799
# translating...
# decoding...
# Selecting reviews 4800 until 4831
# translating...
# decoding...
# Selecting reviews 4832 until 4863
# translating...
# decoding...
# Selecting reviews 4864 until 4895
# translating...
# decoding...
# Selecting reviews 4896 until 4927
# translating...
# decoding...
# Selecting reviews 4928 until 4959
# translating...
# decoding...
# Selecting reviews 4960 until 4991
# translating...
# decoding...
# Selecting reviews 4992 until 5023
# translating...
# decoding...
# Selecting reviews 5024 until 5055
# translating...
# decoding...
# Selecting reviews 5056 until 5087
# translating...
# decoding...
# Selecting reviews 5088 until 5119
# translating...
# decoding...
# Selecting reviews 5120 until 5151
# translating...
# decoding...
# Selecting reviews 5152 until 5183
# translating...
# decoding...
# Selecting reviews 5184 until 5215
# translating...
# decoding...
# Selecting reviews 5216 until 5247
# translating...
# decoding...
# Selecting reviews 5248 until 5279
# translating...
# decoding...
# Selecting reviews 5280 until 5311
# translating...
# decoding...
# Selecting reviews 5312 until 5343
# translating...
# decoding...
# Selecting reviews 5344 until 5375
# translating...
# decoding...
# Selecting reviews 5376 until 5407
# translating...
# decoding...
# Selecting reviews 5408 until 5439
# translating...
# decoding...
# Selecting reviews 5440 until 5471
# translating...
# decoding...
# Selecting reviews 5472 until 5503
# translating...
# decoding...
# Selecting reviews 5504 until 5535
# translating...
# decoding...
# Selecting reviews 5536 until 5567
# translating...
# decoding...
# Selecting reviews 5568 until 5599
# translating...
# decoding...
# Selecting reviews 5600 until 5631
# translating...
# decoding...
# Selecting reviews 5632 until 5663
# translating...
# decoding...
# Selecting reviews 5664 until 5695
# translating...
# decoding...
# Selecting reviews 5696 until 5727
# translating...
# decoding...
# Selecting reviews 5728 until 5759
# translating...
# decoding...
# Selecting reviews 7488 until 7519
# translating...
# decoding...
# Selecting reviews 7520 until 7551
# translating...
# decoding...
# Selecting reviews 7552 until 7583
# translating...
# decoding...
# Selecting reviews 7584 until 7615
# translating...
# decoding...
# Selecting reviews 7616 until 7647
# translating...
# decoding...
# Selecting reviews 7648 until 7679
# translating...
# decoding...
# Selecting reviews 7680 until 7711
# translating...
# decoding...
# Selecting reviews 7712 until 7743
# translating...
# decoding...
# Selecting reviews 7744 until 7775
# translating...
# decoding...
# Selecting reviews 7776 until 7807
# translating...
# decoding...
# Selecting reviews 7808 until 7839
# translating...
# decoding...
# Selecting reviews 7840 until 7871
# translating...
# decoding...
# Selecting reviews 7872 until 7903
# translating...
# decoding...
# Selecting reviews 7904 until 7935
# translating...
# decoding...
# Selecting reviews 7936 until 7967
# translating...
# decoding...
# Selecting reviews 7968 until 7999
# translating...
# decoding...
# Selecting reviews 8000 until 8031
# translating...
# decoding...
# Selecting reviews 8032 until 8063
# translating...
# decoding...
# Selecting reviews 8064 until 8095
# translating...
# decoding...
# Selecting reviews 8096 until 8127
# translating...
# decoding...
# Selecting reviews 8128 until 8159
# translating...
# decoding...
# Selecting reviews 8160 until 8191
# translating...
# decoding...
# Selecting reviews 8192 until 8223
# translating...
# decoding...
# Selecting reviews 8224 until 8255
# translating...
# decoding...
# Selecting reviews 8256 until 8287
# translating...
# decoding...
# Selecting reviews 8288 until 8319
# translating...
# decoding...
# Selecting reviews 8320 until 8351
# translating...
# decoding...
# Selecting reviews 8352 until 8383
# translating...
# decoding...
# Selecting reviews 8384 until 8415
# translating...
# decoding...
# Selecting reviews 8416 until 8447
# translating...
# decoding...
# Selecting reviews 8448 until 8479
# translating...
# decoding...
# Selecting reviews 8480 until 8511
# translating...
# decoding...
# Selecting reviews 8512 until 8543
# translating...
# decoding...
# Selecting reviews 8544 until 8575
# translating...
# decoding...
# Selecting reviews 8576 until 8607
# translating...
# decoding...
# Selecting reviews 8608 until 8639
# translating...
# decoding...
# Selecting reviews 8640 until 8671
# translating...
# decoding...
# Selecting reviews 8672 until 8703
# translating...
# decoding...
# Selecting reviews 8704 until 8735
# translating...
# decoding...
# Selecting reviews 8736 until 8767
# translating...
# decoding...
# Selecting reviews 8768 until 8799
# translating...
# decoding...
# Selecting reviews 8800 until 8831
# translating...
# decoding...
# Selecting reviews 8832 until 8863
# translating...
# decoding...
# Selecting reviews 8864 until 8895
# translating...
# decoding...
# Selecting reviews 8896 until 8927
# translating...
# decoding...
# Selecting reviews 8928 until 8959
# translating...
# decoding...
# Selecting reviews 8960 until 8991
# translating...
# decoding...
# Selecting reviews 8992 until 9023
# translating...
# decoding...
# Selecting reviews 9024 until 9055
# translating...
# decoding...
# Selecting reviews 9056 until 9087
# translating...
# decoding...
# Selecting reviews 9088 until 9119
# translating...
# decoding...
# Selecting reviews 9120 until 9151
# translating...
# decoding...
# Selecting reviews 9152 until 9183
# translating...
# decoding...
# Selecting reviews 9184 until 9215
# translating...
# decoding...
# Selecting reviews 10944 until 10975
# translating...
# decoding...
# Selecting reviews 10976 until 11007
# translating...
# decoding...
# Selecting reviews 11008 until 11039
# translating...
# decoding...
# Selecting reviews 11040 until 11071
# translating...
# decoding...
# Selecting reviews 11072 until 11103
# translating...
# decoding...
# Selecting reviews 11104 until 11135
# translating...
# decoding...
# Selecting reviews 11136 until 11167
# translating...
# decoding...
# Selecting reviews 11168 until 11199
# translating...
# decoding...
# Selecting reviews 11200 until 11231
# translating...
# decoding...
# Selecting reviews 11232 until 11263
# translating...
# decoding...
# Selecting reviews 11264 until 11295
# translating...
# decoding...
# Selecting reviews 11296 until 11327
# translating...
# decoding...
# Selecting reviews 11328 until 11359
# translating...
# decoding...
# Selecting reviews 11360 until 11391
# translating...
# decoding...
# Selecting reviews 11392 until 11423
# translating...
# decoding...
# Selecting reviews 11424 until 11455
# translating...
# decoding...
# Selecting reviews 11456 until 11487
# translating...
# decoding...
# Selecting reviews 11488 until 11519
# translating...
# decoding...
# Selecting reviews 11520 until 11551
# translating...
# decoding...
# Selecting reviews 11552 until 11583
# translating...
# decoding...
# Selecting reviews 11584 until 11615
# translating...
# decoding...
# Selecting reviews 11616 until 11647
# translating...
# decoding...
# Selecting reviews 11648 until 11679
# translating...
# decoding...
# Selecting reviews 11680 until 11711
# translating...
# decoding...
# Selecting reviews 11712 until 11743
# translating...
# decoding...
# Selecting reviews 11744 until 11775
# translating...
# decoding...
# Selecting reviews 11776 until 11807
# translating...
# decoding...
# Selecting reviews 11808 until 11839
# translating...
# decoding...
# Selecting reviews 11840 until 11871
# translating...
# decoding...
# Selecting reviews 11872 until 11903
# translating...
# decoding...
# Selecting reviews 11904 until 11935
# translating...
# decoding...
# Selecting reviews 11936 until 11967
# translating...
# decoding...
# Selecting reviews 11968 until 11999
# translating...
# decoding...
# Selecting reviews 12000 until 12031
# translating...
# decoding...
# Selecting reviews 12032 until 12063
# translating...
# decoding...
# Selecting reviews 12064 until 12095
# translating...
# decoding...
# Selecting reviews 12096 until 12127
# translating...
# decoding...
# Selecting reviews 12128 until 12159
# translating...
# decoding...
# Selecting reviews 12160 until 12191
# translating...
# decoding...
# Selecting reviews 12192 until 12223
# translating...
# decoding...
# Selecting reviews 12224 until 12255
# translating...
# decoding...
# Selecting reviews 12256 until 12287
# translating...
# decoding...
# Selecting reviews 12288 until 12319
# translating...
# decoding...
# Selecting reviews 12320 until 12351
# translating...
# decoding...
# Selecting reviews 12352 until 12383
# translating...
# decoding...
# Selecting reviews 12384 until 12415
# translating...
# decoding...
# Selecting reviews 12416 until 12447
# translating...
# decoding...
# Selecting reviews 12448 until 12479
# translating...
# decoding...
# Selecting reviews 12480 until 12511
# translating...
# decoding...
# Selecting reviews 12512 until 12543
# translating...
# decoding...
# Selecting reviews 12544 until 12575
# translating...
# decoding...
# Selecting reviews 12576 until 12607
# translating...
# decoding...
# Selecting reviews 12608 until 12639
# translating...
# decoding...
# Selecting reviews 12640 until 12671
# translating...
# decoding...
# Selecting reviews 12672 until 12703
# translating...
# decoding...
# Selecting reviews 12704 until 12735
# translating...
# decoding...
# Selecting reviews 12736 until 12767
# translating...
# decoding...
# Selecting reviews 12768 until 12799
# translating...
# decoding...
# Selecting reviews 12800 until 12831
# translating...
# decoding...
# Selecting reviews 12832 until 12863
# translating...
# decoding...
# Selecting reviews 12864 until 12895
# translating...
# decoding...
# Selecting reviews 12896 until 12927
# translating...
# decoding...
# Selecting reviews 12928 until 12959
# translating...
# decoding...
# Selecting reviews 12960 until 12991
# translating...
# decoding...
# Selecting reviews 12992 until 13023
# translating...
# decoding...
# Selecting reviews 13024 until 13055
# translating...
# decoding...
# Selecting reviews 13056 until 13087
# translating...
# decoding...
# Selecting reviews 13088 until 13119
# translating...
# decoding...
# Selecting reviews 13120 until 13151
# translating...
# decoding...
# Selecting reviews 13152 until 13183
# translating...
# decoding...
# Selecting reviews 13184 until 13215
# translating...
# decoding...
# Selecting reviews 13216 until 13247
# translating...
# decoding...
# Selecting reviews 13248 until 13279
# translating...
# decoding...
# Selecting reviews 13280 until 13311
# translating...
# decoding...
# Selecting reviews 13312 until 13343
# translating...
# decoding...
# Selecting reviews 13344 until 13375
# translating...
# decoding...
# Selecting reviews 13376 until 13407
# translating...
# decoding...
# Selecting reviews 13408 until 13439
# translating...
# decoding...
# Selecting reviews 13440 until 13471
# translating...
# decoding...
# Selecting reviews 13472 until 13503
# translating...
# decoding...
# Selecting reviews 13504 until 13535
# translating...
# decoding...
# Selecting reviews 13536 until 13567
# translating...
# decoding...
# Selecting reviews 13568 until 13599
# translating...
# decoding...
# Selecting reviews 13600 until 13631
# translating...
# decoding...
# Selecting reviews 13632 until 13663
# translating...
# decoding...
# Selecting reviews 13664 until 13695
# translating...
# decoding...
# Selecting reviews 13696 until 13727
# translating...
# decoding...
# Selecting reviews 13728 until 13759
# translating...
# decoding...
# Selecting reviews 13760 until 13791
# translating...
# decoding...
# Selecting reviews 13792 until 13823
# translating...
# decoding...
# Selecting reviews 13824 until 13855
# translating...
# decoding...
# Selecting reviews 13856 until 13887
# translating...
# decoding...
# Selecting reviews 13888 until 13919
# translating...
# decoding...
# Selecting reviews 13920 until 13951
# translating...
# decoding...
# Selecting reviews 13952 until 13983
# translating...
# decoding...
# Selecting reviews 13984 until 14015
# translating...
# decoding...
# Selecting reviews 14016 until 14047
# translating...
# decoding...
# Selecting reviews 14048 until 14079
# translating...
# decoding...
# Selecting reviews 14080 until 14111
# translating...
# decoding...
# Selecting reviews 14112 until 14143
# translating...
# decoding...
# Selecting reviews 14144 until 14175
# translating...
# decoding...
# Selecting reviews 14176 until 14207
# translating...
# decoding...
# Selecting reviews 14208 until 14239
# translating...
# decoding...
# Selecting reviews 14240 until 14271
# translating...
# decoding...
# Selecting reviews 14272 until 14303
# translating...
# decoding...
# Selecting reviews 14304 until 14335
# translating...
# decoding...
# Selecting reviews 14336 until 14367
# translating...
# decoding...
# Selecting reviews 14368 until 14399
# translating...
# decoding...
# Selecting reviews 14400 until 14431
# translating...
# decoding...
# Selecting reviews 14432 until 14463
# translating...
# decoding...
# Selecting reviews 14464 until 14495
# translating...
# decoding...
# Selecting reviews 14496 until 14527
# translating...
# decoding...
# Selecting reviews 14528 until 14559
# translating...
# decoding...
# Selecting reviews 14560 until 14591
# translating...
# decoding...
# Selecting reviews 14592 until 14623
# translating...
# decoding...
# Selecting reviews 14624 until 14640
# translating...
# decoding...

# %%
len(translated), len(df)
# Out:
# (14640, 14640)

# %%
df['text_de'] = translated

# %%
df[['text', 'text_de']].tail()
# Out:
#                                                                                                                                                   text  \
# 14635                                                                     @SouthwestAir How do I stop getting credit card apps? I already have a card!
# 14636    @united I was sincerely thanking the pilot of flight 4461 of braving the snow and getting me home amongst many other Cancelled Flightlations.
# 14637  @united and btw, the @Virgin and @JetBlue managed on time departures same time same destination- &amp; wouldn't take away a 9year old kids bag!
# 14638                                                  @USAirways #not happy, wife 40th Bday trip. would like to be fully compensated for both flights
# 14639                                             @Delta @JetBlue received a voucher but if you want to improve relations be up front with passengers.
#
#                                                                                                                                                                          text_de
# 14635                                                                                @SouthwestAir Wie höre ich auf, Kreditkarten-Apps zu bekommen? Ich habe bereits eine Karte!
# 14636  @united Ich bedankte mich aufrichtig bei dem Piloten des Fluges 4461, der den Schnee ausbrütete und mich unter vielen anderen Cancelled Flightlations nach Hause brachte.
# 14637              @united und btw, die @Virgin und @JetBlue verwaltet auf Zeit Abfahrten gleichzeitig gleiche Ziel- &amp; würde nicht wegnehmen eine 9 Jahre alte Kindertasche!
# 14638                                                                    @USAirways #nicht glücklich, Frau 40. Bday Reise. möchte für beide Flüge vollständig entschädigt werden
# 14639                                               @Delta @JetBlue erhielt einen Gutschein, aber wenn Sie die Beziehungen zu den Passagieren verbessern wollen, sind Sie vorne.

# %% [markdown]
# Reversing source and target language to translate back from German to English

# %%
mname = f'Helsinki-NLP/opus-mt-{trg}-{src}'
mname
# Out:
# 'Helsinki-NLP/opus-mt-de-en'

# %%
tokenizer = MarianTokenizer.from_pretrained(mname)
model = MarianMTModel.from_pretrained(mname)
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils.py:831: FutureWarning: Parameter max_len is deprecated and will be removed in a future release. Use model_max_length instead.
#   category=FutureWarning,

# %%
model.cuda();

# %% [markdown]
# Now translating the German translations back to English

# %%
bs = 32
translated_bwd = []
for i in range(int(len(df)/bs)+1):
    if len(df)-(i*bs)<=bs:
        print(f'Selecting reviews {i*bs} until {len(df)}')
        src_texts=df.loc[i*bs:,'text_de']
    else: 
        print(f'Selecting reviews {i*bs} until {i*bs+bs-1}')
        src_texts=df.loc[i*bs:i*bs+bs-1,'text_de']
    batch = tokenizer.prepare_translation_batch(src_texts=src_texts)
    print('translating...')
    gen = model.generate(batch.input_ids.cuda())
    print('decoding...')
    decoded = [tokenizer.decode(g, skip_special_tokens=True) for g in gen]
    translated_bwd.extend(decoded)
# Out:
# Selecting reviews 0 until 31
# translating...
# decoding...
# Selecting reviews 32 until 63
# translating...
# decoding...
# Selecting reviews 64 until 95
# translating...
# decoding...
# Selecting reviews 96 until 127
# translating...
# decoding...
# Selecting reviews 128 until 159
# translating...
# decoding...
# Selecting reviews 160 until 191
# translating...
# decoding...
# Selecting reviews 192 until 223
# translating...
# decoding...
# Selecting reviews 224 until 255
# translating...
# decoding...
# Selecting reviews 256 until 287
# translating...
# decoding...
# Selecting reviews 288 until 319
# translating...
# decoding...
# Selecting reviews 320 until 351
# translating...
# decoding...
# Selecting reviews 352 until 383
# translating...
# decoding...
# Selecting reviews 384 until 415
# translating...
# decoding...
# Selecting reviews 416 until 447
# translating...
# decoding...
# Selecting reviews 448 until 479
# translating...
# decoding...
# Selecting reviews 480 until 511
# translating...
# decoding...
# Selecting reviews 512 until 543
# translating...
# decoding...
# Selecting reviews 544 until 575
# translating...
# decoding...
# Selecting reviews 576 until 607
# translating...
# decoding...
# Selecting reviews 608 until 639
# translating...
# decoding...
# Selecting reviews 640 until 671
# translating...
# decoding...
# Selecting reviews 672 until 703
# translating...
# decoding...
# Selecting reviews 704 until 735
# translating...
# decoding...
# Selecting reviews 736 until 767
# translating...
# decoding...
# Selecting reviews 768 until 799
# translating...
# decoding...
# Selecting reviews 800 until 831
# translating...
# decoding...
# Selecting reviews 832 until 863
# translating...
# decoding...
# Selecting reviews 864 until 895
# translating...
# decoding...
# Selecting reviews 896 until 927
# translating...
# decoding...
# Selecting reviews 928 until 959
# translating...
# decoding...
# Selecting reviews 960 until 991
# translating...
# decoding...
# Selecting reviews 992 until 1023
# translating...
# decoding...
# Selecting reviews 1024 until 1055
# translating...
# decoding...
# Selecting reviews 1056 until 1087
# translating...
# decoding...
# Selecting reviews 1088 until 1119
# translating...
# decoding...
# Selecting reviews 1120 until 1151
# translating...
# decoding...
# Selecting reviews 1152 until 1183
# translating...
# decoding...
# Selecting reviews 1184 until 1215
# translating...
# decoding...
# Selecting reviews 1216 until 1247
# translating...
# decoding...
# Selecting reviews 1248 until 1279
# translating...
# decoding...
# Selecting reviews 1280 until 1311
# translating...
# decoding...
# Selecting reviews 1312 until 1343
# translating...
# decoding...
# Selecting reviews 1344 until 1375
# translating...
# decoding...
# Selecting reviews 1376 until 1407
# translating...
# decoding...
# Selecting reviews 1408 until 1439
# translating...
# decoding...
# Selecting reviews 1440 until 1471
# translating...
# decoding...
# Selecting reviews 1472 until 1503
# translating...
# decoding...
# Selecting reviews 1504 until 1535
# translating...
# decoding...
# Selecting reviews 1536 until 1567
# translating...
# decoding...
# Selecting reviews 1568 until 1599
# translating...
# decoding...
# Selecting reviews 1600 until 1631
# translating...
# decoding...
# Selecting reviews 1632 until 1663
# translating...
# decoding...
# Selecting reviews 1664 until 1695
# translating...
# decoding...
# Selecting reviews 1696 until 1727
# translating...
# decoding...
# Selecting reviews 1728 until 1759
# translating...
# decoding...
# Selecting reviews 1760 until 1791
# translating...
# decoding...
# Selecting reviews 1792 until 1823
# translating...
# decoding...
# Selecting reviews 1824 until 1855
# translating...
# decoding...
# Selecting reviews 1856 until 1887
# translating...
# decoding...
# Selecting reviews 1888 until 1919
# translating...
# decoding...
# Selecting reviews 1920 until 1951
# translating...
# decoding...
# Selecting reviews 1952 until 1983
# translating...
# decoding...
# Selecting reviews 1984 until 2015
# translating...
# decoding...
# Selecting reviews 2016 until 2047
# translating...
# decoding...
# Selecting reviews 2048 until 2079
# translating...
# decoding...
# Selecting reviews 2080 until 2111
# translating...
# decoding...
# Selecting reviews 2112 until 2143
# translating...
# decoding...
# Selecting reviews 2144 until 2175
# translating...
# decoding...
# Selecting reviews 2176 until 2207
# translating...
# decoding...
# Selecting reviews 2208 until 2239
# translating...
# decoding...
# Selecting reviews 2240 until 2271
# translating...
# decoding...
# Selecting reviews 2272 until 2303
# translating...
# decoding...
# Selecting reviews 2304 until 2335
# translating...
# decoding...
# Selecting reviews 2336 until 2367
# translating...
# decoding...
# Selecting reviews 2368 until 2399
# translating...
# decoding...
# Selecting reviews 2400 until 2431
# translating...
# decoding...
# Selecting reviews 2432 until 2463
# translating...
# decoding...
# Selecting reviews 2464 until 2495
# translating...
# decoding...
# Selecting reviews 2496 until 2527
# translating...
# decoding...
# Selecting reviews 2528 until 2559
# translating...
# decoding...
# Selecting reviews 2560 until 2591
# translating...
# decoding...
# Selecting reviews 2592 until 2623
# translating...
# decoding...
# Selecting reviews 2624 until 2655
# translating...
# decoding...
# Selecting reviews 2656 until 2687
# translating...
# decoding...
# Selecting reviews 2688 until 2719
# translating...
# decoding...
# Selecting reviews 2720 until 2751
# translating...
# decoding...
# Selecting reviews 2752 until 2783
# translating...
# decoding...
# Selecting reviews 2784 until 2815
# translating...
# decoding...
# Selecting reviews 2816 until 2847
# translating...
# decoding...
# Selecting reviews 2848 until 2879
# translating...
# decoding...
# Selecting reviews 2880 until 2911
# translating...
# decoding...
# Selecting reviews 2912 until 2943
# translating...
# decoding...
# Selecting reviews 2944 until 2975
# translating...
# decoding...
# Selecting reviews 2976 until 3007
# translating...
# decoding...
# Selecting reviews 3008 until 3039
# translating...
# decoding...
# Selecting reviews 3040 until 3071
# translating...
# decoding...
# Selecting reviews 3072 until 3103
# translating...
# decoding...
# Selecting reviews 3104 until 3135
# translating...
# decoding...
# Selecting reviews 3136 until 3167
# translating...
# decoding...
# Selecting reviews 3168 until 3199
# translating...
# decoding...
# Selecting reviews 3200 until 3231
# translating...
# decoding...
# Selecting reviews 3232 until 3263
# translating...
# decoding...
# Selecting reviews 3264 until 3295
# translating...
# decoding...
# Selecting reviews 3296 until 3327
# translating...
# decoding...
# Selecting reviews 3328 until 3359
# translating...
# decoding...
# Selecting reviews 3360 until 3391
# translating...
# decoding...
# Selecting reviews 3392 until 3423
# translating...
# decoding...
# Selecting reviews 3424 until 3455
# translating...
# decoding...
# Selecting reviews 3456 until 3487
# translating...
# decoding...
# Selecting reviews 3488 until 3519
# translating...
# decoding...
# Selecting reviews 3520 until 3551
# translating...
# decoding...
# Selecting reviews 3552 until 3583
# translating...
# decoding...
# Selecting reviews 3584 until 3615
# translating...
# decoding...
# Selecting reviews 3616 until 3647
# translating...
# decoding...
# Selecting reviews 3648 until 3679
# translating...
# decoding...
# Selecting reviews 3680 until 3711
# translating...
# decoding...
# Selecting reviews 3712 until 3743
# translating...
# decoding...
# Selecting reviews 3744 until 3775
# translating...
# decoding...
# Selecting reviews 3776 until 3807
# translating...
# decoding...
# Selecting reviews 3808 until 3839
# translating...
# decoding...
# Selecting reviews 3840 until 3871
# translating...
# decoding...
# Selecting reviews 3872 until 3903
# translating...
# decoding...
# Selecting reviews 3904 until 3935
# translating...
# decoding...
# Selecting reviews 3936 until 3967
# translating...
# decoding...
# Selecting reviews 3968 until 3999
# translating...
# decoding...
# Selecting reviews 4000 until 4031
# translating...
# decoding...
# Selecting reviews 4032 until 4063
# translating...
# decoding...
# Selecting reviews 4064 until 4095
# translating...
# decoding...
# Selecting reviews 4096 until 4127
# translating...
# decoding...
# Selecting reviews 4128 until 4159
# translating...
# decoding...
# Selecting reviews 4160 until 4191
# translating...
# decoding...
# Selecting reviews 4192 until 4223
# translating...
# decoding...
# Selecting reviews 4224 until 4255
# translating...
# decoding...
# Selecting reviews 4256 until 4287
# translating...
# decoding...
# Selecting reviews 4288 until 4319
# translating...
# decoding...
# Selecting reviews 4320 until 4351
# translating...
# decoding...
# Selecting reviews 4352 until 4383
# translating...
# decoding...
# Selecting reviews 4384 until 4415
# translating...
# decoding...
# Selecting reviews 4416 until 4447
# translating...
# decoding...
# Selecting reviews 4448 until 4479
# translating...
# decoding...
# Selecting reviews 4480 until 4511
# translating...
# decoding...
# Selecting reviews 4512 until 4543
# translating...
# decoding...
# Selecting reviews 4544 until 4575
# translating...
# decoding...
# Selecting reviews 4576 until 4607
# translating...
# decoding...
# Selecting reviews 4608 until 4639
# translating...
# decoding...
# Selecting reviews 4640 until 4671
# translating...
# decoding...
# Selecting reviews 4672 until 4703
# translating...
# decoding...
# Selecting reviews 4704 until 4735
# translating...
# decoding...
# Selecting reviews 4736 until 4767
# translating...
# decoding...
# Selecting reviews 4768 until 4799
# translating...
# decoding...
# Selecting reviews 4800 until 4831
# translating...
# decoding...
# Selecting reviews 4832 until 4863
# translating...
# decoding...
# Selecting reviews 4864 until 4895
# translating...
# decoding...
# Selecting reviews 4896 until 4927
# translating...
# decoding...
# Selecting reviews 4928 until 4959
# translating...
# decoding...
# Selecting reviews 4960 until 4991
# translating...
# decoding...
# Selecting reviews 4992 until 5023
# translating...
# decoding...
# Selecting reviews 5024 until 5055
# translating...
# decoding...
# Selecting reviews 5056 until 5087
# translating...
# decoding...
# Selecting reviews 5088 until 5119
# translating...
# decoding...
# Selecting reviews 5120 until 5151
# translating...
# decoding...
# Selecting reviews 5152 until 5183
# translating...
# decoding...
# Selecting reviews 5184 until 5215
# translating...
# decoding...
# Selecting reviews 5216 until 5247
# translating...
# decoding...
# Selecting reviews 5248 until 5279
# translating...
# decoding...
# Selecting reviews 5280 until 5311
# translating...
# decoding...
# Selecting reviews 12224 until 12255
# translating...
# decoding...
# Selecting reviews 12256 until 12287
# translating...
# decoding...
# Selecting reviews 12288 until 12319
# translating...
# decoding...
# Selecting reviews 12320 until 12351
# translating...
# decoding...
# Selecting reviews 12352 until 12383
# translating...
# decoding...
# Selecting reviews 12384 until 12415
# translating...
# decoding...
# Selecting reviews 12416 until 12447
# translating...
# decoding...
# Selecting reviews 12448 until 12479
# translating...
# decoding...
# Selecting reviews 12480 until 12511
# translating...
# decoding...
# Selecting reviews 12512 until 12543
# translating...
# decoding...
# Selecting reviews 12544 until 12575
# translating...
# decoding...
# Selecting reviews 12576 until 12607
# translating...
# decoding...
# Selecting reviews 12608 until 12639
# translating...
# decoding...
# Selecting reviews 12640 until 12671
# translating...
# decoding...
# Selecting reviews 12672 until 12703
# translating...
# decoding...
# Selecting reviews 12704 until 12735
# translating...
# decoding...
# Selecting reviews 12736 until 12767
# translating...
# decoding...
# Selecting reviews 12768 until 12799
# translating...
# decoding...
# Selecting reviews 12800 until 12831
# translating...
# decoding...
# Selecting reviews 12832 until 12863
# translating...
# decoding...
# Selecting reviews 12864 until 12895
# translating...
# decoding...
# Selecting reviews 12896 until 12927
# translating...
# decoding...
# Selecting reviews 12928 until 12959
# translating...
# decoding...
# Selecting reviews 12960 until 12991
# translating...
# decoding...
# Selecting reviews 12992 until 13023
# translating...
# decoding...
# Selecting reviews 13024 until 13055
# translating...
# decoding...
# Selecting reviews 13056 until 13087
# translating...
# decoding...
# Selecting reviews 13088 until 13119
# translating...
# decoding...
# Selecting reviews 13120 until 13151
# translating...
# decoding...
# Selecting reviews 13152 until 13183
# translating...
# decoding...
# Selecting reviews 13184 until 13215
# translating...
# decoding...
# Selecting reviews 13216 until 13247
# translating...
# decoding...
# Selecting reviews 13248 until 13279
# translating...
# decoding...
# Selecting reviews 13280 until 13311
# translating...
# decoding...
# Selecting reviews 13312 until 13343
# translating...
# decoding...
# Selecting reviews 13344 until 13375
# translating...
# decoding...
# Selecting reviews 13376 until 13407
# translating...
# decoding...
# Selecting reviews 13408 until 13439
# translating...
# decoding...
# Selecting reviews 13440 until 13471
# translating...
# decoding...
# Selecting reviews 13472 until 13503
# translating...
# decoding...
# Selecting reviews 13504 until 13535
# translating...
# decoding...
# Selecting reviews 13536 until 13567
# translating...
# decoding...
# Selecting reviews 13568 until 13599
# translating...
# decoding...
# Selecting reviews 13600 until 13631
# translating...
# decoding...
# Selecting reviews 13632 until 13663
# translating...
# decoding...
# Selecting reviews 13664 until 13695
# translating...
# decoding...
# Selecting reviews 13696 until 13727
# translating...
# decoding...
# Selecting reviews 13728 until 13759
# translating...
# decoding...
# Selecting reviews 13760 until 13791
# translating...
# decoding...
# Selecting reviews 13792 until 13823
# translating...
# decoding...
# Selecting reviews 13824 until 13855
# translating...
# decoding...
# Selecting reviews 13856 until 13887
# translating...
# decoding...
# Selecting reviews 13888 until 13919
# translating...
# decoding...
# Selecting reviews 13920 until 13951
# translating...
# decoding...
# Selecting reviews 13952 until 13983
# translating...
# decoding...
# Selecting reviews 13984 until 14015
# translating...
# decoding...
# Selecting reviews 14016 until 14047
# translating...
# decoding...
# Selecting reviews 14048 until 14079
# translating...
# decoding...
# Selecting reviews 14080 until 14111
# translating...
# decoding...
# Selecting reviews 14112 until 14143
# translating...
# decoding...
# Selecting reviews 14144 until 14175
# translating...
# decoding...
# Selecting reviews 14176 until 14207
# translating...
# decoding...
# Selecting reviews 14208 until 14239
# translating...
# decoding...
# Selecting reviews 14240 until 14271
# translating...
# decoding...
# Selecting reviews 14272 until 14303
# translating...
# decoding...
# Selecting reviews 14304 until 14335
# translating...
# decoding...
# Selecting reviews 14336 until 14367
# translating...
# decoding...
# Selecting reviews 14368 until 14399
# translating...
# decoding...
# Selecting reviews 14400 until 14431
# translating...
# decoding...
# Selecting reviews 14432 until 14463
# translating...
# decoding...
# Selecting reviews 14464 until 14495
# translating...
# decoding...
# Selecting reviews 14496 until 14527
# translating...
# decoding...
# Selecting reviews 14528 until 14559
# translating...
# decoding...
# Selecting reviews 14560 until 14591
# translating...
# decoding...
# Selecting reviews 14592 until 14623
# translating...
# decoding...
# Selecting reviews 14624 until 14640
# translating...
# decoding...

# %%
len(df), len(translated_bwd)
# Out:
# (14640, 14640)

# %% [markdown]
# Just some pandas operations to get the data into the right format

# %%
df_new = df[['airline_sentiment', 'airline_sentiment_confidence', 'text', 'is_valid', 'name']]

# %%
df_new.loc[:,'text'] = translated_bwd

# %%
df_new.loc[:,'name'] = True

# %%
df_new.rename(columns={'name':'translated'}, inplace=True)

# %%
df_new.head()
# Out:
#   airline_sentiment  airline_sentiment_confidence  \
# 0          negative                        1.0000
# 1           neutral                        0.6600
# 2          negative                        1.0000
# 3           neutral                        0.6694
# 4          negative                        1.0000
#
#                                                                                                        text  \
# 0                                         @united sit on UAL 683 - a comedy of mistakes. UAL is incompetent
# 1  @SouthwestAir When is the last chance to get #DestinationDragons tickets? I would die of luck if I won -
# 2   @united Why the hell are my miles running out? Was really excited enough for a free flight in 10 years.
# 3                               @SouthwestAir when we can expect customer service to be available in Dallas
# 4                                    We waited 40 min for our bags after a 45 min flight #nomorecheckedbags
#
#    is_valid  translated
# 0     False        True
# 1     False        True
# 2     False        True
# 3     False        True
# 4     False        True

# %%
df_new.to_csv('Tweets_valid_translated.csv', index=False)

# %%
df_full = pd.concat([df, df_new]).reset_index(drop=True)

# %%
len(df_full)
# Out:
# 29280

# %%
df_full[df_full.translated==True].head()
# Out:
#        tweet_id airline_sentiment  airline_sentiment_confidence  \
# 14640       NaN          negative                        1.0000
# 14641       NaN           neutral                        0.6600
# 14642       NaN          negative                        1.0000
# 14643       NaN           neutral                        0.6694
# 14644       NaN          negative                        1.0000
#
#       negativereason  negativereason_confidence airline  \
# 14640            NaN                        NaN     NaN
# 14641            NaN                        NaN     NaN
# 14642            NaN                        NaN     NaN
# 14643            NaN                        NaN     NaN
# 14644            NaN                        NaN     NaN
#
#       airline_sentiment_gold name negativereason_gold  retweet_count text_old  \
# 14640                    NaN  NaN                 NaN            NaN      NaN
# 14641                    NaN  NaN                 NaN            NaN      NaN
# 14642                    NaN  NaN                 NaN            NaN      NaN
# 14643                    NaN  NaN                 NaN            NaN      NaN
# 14644                    NaN  NaN                 NaN            NaN      NaN
#
#       tweet_coord tweet_created tweet_location user_timezone  is_valid  \
# 14640         NaN           NaN            NaN           NaN     False
# 14641         NaN           NaN            NaN           NaN     False
# 14642         NaN           NaN            NaN           NaN     False
# 14643         NaN           NaN            NaN           NaN     False
# 14644         NaN           NaN            NaN           NaN     False
#
#                                                                                                            text  \
# 14640                                         @united sit on UAL 683 - a comedy of mistakes. UAL is incompetent
# 14641  @SouthwestAir When is the last chance to get #DestinationDragons tickets? I would die of luck if I won -
# 14642   @united Why the hell are my miles running out? Was really excited enough for a free flight in 10 years.
# 14643                               @SouthwestAir when we can expect customer service to be available in Dallas
# 14644                                    We waited 40 min for our bags after a 45 min flight #nomorecheckedbags
#
#       text_de translated
# 14640     NaN       True
# 14641     NaN       True
# 14642     NaN       True
# 14643     NaN       True
# 14644     NaN       True

# %%
df_full.to_csv('Tweets_valid_full.csv', index=False)

# %% [markdown]
# ## Back translation part 2: English-French-English

# %% [markdown]
# Doing exactly the same as above but using French as intermediate language instead of German. Also note that I only use this second type of back-translate to further increase the number of neutral and positive training examples in order to have a balanced training dataset. Negative examples and the validation set are excluded for this step.

# %%
df = pd.read_csv('Tweets_valid_full.csv')

# %%
idx = df[df.translated!=True].index
df.loc[idx,'translated'] = False

# %%
cnt = Counter(df[df.is_valid==False].airline_sentiment)
cnt
# Out:
# Counter({'negative': 14624, 'neutral': 5018, 'positive': 3782})

# %%
diff_neu = int(cnt['negative']/2 - cnt['neutral'])
diff_pos = int(cnt['negative']/2 - cnt['positive'])
diff_neu, diff_pos
# Out:
# (2294, 3530)

# %%
df_transl_neu = df[(df.is_valid==False) & (df.translated==False) & (df.airline_sentiment=='neutral')].sample(n=diff_neu)
df_transl_pos = df[(df.is_valid==False) & (df.airline_sentiment=='positive')].sample(n=diff_pos)
len(df_transl_neu), len(df_transl_pos)
# Out:
# (2294, 3530)

# %%
df_transl = pd.concat([df_transl_neu, df_transl_pos]).reset_index(drop=True)
len(df_transl)
# Out:
# 5824

# %%
src = 'en'
trg = 'fr'

# %%
mname = f'Helsinki-NLP/opus-mt-{src}-{trg}'
mname
# Out:
# 'Helsinki-NLP/opus-mt-en-fr'

# %%
tokenizer = MarianTokenizer.from_pretrained(mname)
model = MarianMTModel.from_pretrained(mname)
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils.py:831: FutureWarning: Parameter max_len is deprecated and will be removed in a future release. Use model_max_length instead.
#   category=FutureWarning,

# %%
model.cuda();

# %%
bs = 32
translated = []
for i in range(int(len(df_transl)/bs)):
    if len(df_transl)-(i*bs)<=bs:
        print(f'Selecting reviews {i*bs} until {len(df_transl)}')
        src_texts=df_transl.loc[i*bs:,'text']
    else: 
        print(f'Selecting reviews {i*bs} until {i*bs+bs-1}')
        src_texts=df_transl.loc[i*bs:i*bs+bs-1,'text']
    batch = tokenizer.prepare_translation_batch(src_texts=src_texts)
    batch
    print('translating...')
    gen = model.generate(batch.input_ids.cuda())
    print('decoding...')
    decoded = [tokenizer.decode(g, skip_special_tokens=True) for g in gen]
    translated.extend(decoded)
# Out:
# Selecting reviews 0 until 31
# translating...
# decoding...
# Selecting reviews 32 until 63
# translating...
# decoding...
# Selecting reviews 64 until 95
# translating...
# decoding...
# Selecting reviews 96 until 127
# translating...
# decoding...
# Selecting reviews 128 until 159
# translating...
# decoding...
# Selecting reviews 160 until 191
# translating...
# decoding...
# Selecting reviews 192 until 223
# translating...
# decoding...
# Selecting reviews 224 until 255
# translating...
# decoding...
# Selecting reviews 256 until 287
# translating...
# decoding...
# Selecting reviews 288 until 319
# translating...
# decoding...
# Selecting reviews 320 until 351
# translating...
# decoding...
# Selecting reviews 352 until 383
# translating...
# decoding...
# Selecting reviews 384 until 415
# translating...
# decoding...
# Selecting reviews 416 until 447
# translating...
# decoding...
# Selecting reviews 448 until 479
# translating...
# decoding...
# Selecting reviews 480 until 511
# translating...
# decoding...
# Selecting reviews 512 until 543
# translating...
# decoding...
# Selecting reviews 544 until 575
# translating...
# decoding...
# Selecting reviews 576 until 607
# translating...
# decoding...
# Selecting reviews 608 until 639
# translating...
# decoding...
# Selecting reviews 640 until 671
# translating...
# decoding...
# Selecting reviews 672 until 703
# translating...
# decoding...
# Selecting reviews 704 until 735
# translating...
# decoding...
# Selecting reviews 736 until 767
# translating...
# decoding...
# Selecting reviews 768 until 799
# translating...
# decoding...
# Selecting reviews 800 until 831
# translating...
# decoding...
# Selecting reviews 832 until 863
# translating...
# decoding...
# Selecting reviews 864 until 895
# translating...
# decoding...
# Selecting reviews 896 until 927
# translating...
# decoding...
# Selecting reviews 928 until 959
# translating...
# decoding...
# Selecting reviews 960 until 991
# translating...
# decoding...
# Selecting reviews 992 until 1023
# translating...
# decoding...
# Selecting reviews 1024 until 1055
# translating...
# decoding...
# Selecting reviews 1056 until 1087
# translating...
# decoding...
# Selecting reviews 1088 until 1119
# translating...
# decoding...
# Selecting reviews 1120 until 1151
# translating...
# decoding...
# Selecting reviews 1152 until 1183
# translating...
# decoding...
# Selecting reviews 1184 until 1215
# translating...
# decoding...
# Selecting reviews 1216 until 1247
# translating...
# decoding...
# Selecting reviews 1248 until 1279
# translating...
# decoding...
# Selecting reviews 1280 until 1311
# translating...
# decoding...
# Selecting reviews 1312 until 1343
# translating...
# decoding...
# Selecting reviews 1344 until 1375
# translating...
# decoding...
# Selecting reviews 1376 until 1407
# translating...
# decoding...
# Selecting reviews 1408 until 1439
# translating...
# decoding...
# Selecting reviews 1440 until 1471
# translating...
# decoding...
# Selecting reviews 1472 until 1503
# translating...
# decoding...
# Selecting reviews 1504 until 1535
# translating...
# decoding...
# Selecting reviews 1536 until 1567
# translating...
# decoding...
# Selecting reviews 1568 until 1599
# translating...
# decoding...
# Selecting reviews 1600 until 1631
# translating...
# decoding...
# Selecting reviews 1632 until 1663
# translating...
# decoding...
# Selecting reviews 1664 until 1695
# translating...
# decoding...
# Selecting reviews 1696 until 1727
# translating...
# decoding...
# Selecting reviews 1728 until 1759
# translating...
# decoding...
# Selecting reviews 1760 until 1791
# translating...
# decoding...
# Selecting reviews 1792 until 1823
# translating...
# decoding...
# Selecting reviews 1824 until 1855
# translating...
# decoding...
# Selecting reviews 1856 until 1887
# translating...
# decoding...
# Selecting reviews 1888 until 1919
# translating...
# decoding...
# Selecting reviews 1920 until 1951
# translating...
# decoding...
# Selecting reviews 1952 until 1983
# translating...
# decoding...
# Selecting reviews 1984 until 2015
# translating...
# decoding...
# Selecting reviews 2016 until 2047
# translating...
# decoding...
# Selecting reviews 2048 until 2079
# translating...
# decoding...
# Selecting reviews 2080 until 2111
# translating...
# decoding...
# Selecting reviews 2112 until 2143
# translating...
# decoding...
# Selecting reviews 2144 until 2175
# translating...
# decoding...
# Selecting reviews 2176 until 2207
# translating...
# decoding...
# Selecting reviews 2208 until 2239
# translating...
# decoding...
# Selecting reviews 2240 until 2271
# translating...
# decoding...
# Selecting reviews 2272 until 2303
# translating...
# decoding...
# Selecting reviews 2304 until 2335
# translating...
# decoding...
# Selecting reviews 2336 until 2367
# translating...
# decoding...
# Selecting reviews 2368 until 2399
# translating...
# decoding...
# Selecting reviews 2400 until 2431
# translating...
# decoding...
# Selecting reviews 2432 until 2463
# translating...
# decoding...
# Selecting reviews 2464 until 2495
# translating...
# decoding...
# Selecting reviews 2496 until 2527
# translating...
# decoding...
# Selecting reviews 2528 until 2559
# translating...
# decoding...
# Selecting reviews 2560 until 2591
# translating...
# decoding...
# Selecting reviews 2592 until 2623
# translating...
# decoding...
# Selecting reviews 2624 until 2655
# translating...
# decoding...
# Selecting reviews 2656 until 2687
# translating...
# decoding...
# Selecting reviews 2688 until 2719
# translating...
# decoding...
# Selecting reviews 2720 until 2751
# translating...
# decoding...
# Selecting reviews 2752 until 2783
# translating...
# decoding...
# Selecting reviews 2784 until 2815
# translating...
# decoding...
# Selecting reviews 2816 until 2847
# translating...
# decoding...
# Selecting reviews 2848 until 2879
# translating...
# decoding...
# Selecting reviews 2880 until 2911
# translating...
# decoding...
# Selecting reviews 2912 until 2943
# translating...
# decoding...
# Selecting reviews 2944 until 2975
# translating...
# decoding...
# Selecting reviews 2976 until 3007
# translating...
# decoding...
# Selecting reviews 3008 until 3039
# translating...
# decoding...
# Selecting reviews 3040 until 3071
# translating...
# decoding...
# Selecting reviews 3072 until 3103
# translating...
# decoding...
# Selecting reviews 3104 until 3135
# translating...
# decoding...
# Selecting reviews 3136 until 3167
# translating...
# decoding...
# Selecting reviews 3168 until 3199
# translating...
# decoding...
# Selecting reviews 3200 until 3231
# translating...
# decoding...
# Selecting reviews 3232 until 3263
# translating...
# decoding...
# Selecting reviews 3264 until 3295
# translating...
# decoding...
# Selecting reviews 3296 until 3327
# translating...
# decoding...
# Selecting reviews 3328 until 3359
# translating...
# decoding...
# Selecting reviews 3360 until 3391
# translating...
# decoding...
# Selecting reviews 3392 until 3423
# translating...
# decoding...
# Selecting reviews 3424 until 3455
# translating...
# decoding...
# Selecting reviews 3456 until 3487
# translating...
# decoding...
# Selecting reviews 3488 until 3519
# translating...
# decoding...
# Selecting reviews 3520 until 3551
# translating...
# decoding...
# Selecting reviews 3552 until 3583
# translating...
# decoding...
# Selecting reviews 3584 until 3615
# translating...
# decoding...
# Selecting reviews 3616 until 3647
# translating...
# decoding...
# Selecting reviews 3648 until 3679
# translating...
# decoding...
# Selecting reviews 3680 until 3711
# translating...
# decoding...
# Selecting reviews 3712 until 3743
# translating...
# decoding...
# Selecting reviews 3744 until 3775
# translating...
# decoding...
# Selecting reviews 3776 until 3807
# translating...
# decoding...
# Selecting reviews 3808 until 3839
# translating...
# decoding...
# Selecting reviews 3840 until 3871
# translating...
# decoding...
# Selecting reviews 3872 until 3903
# translating...
# decoding...
# Selecting reviews 3904 until 3935
# translating...
# decoding...
# Selecting reviews 3936 until 3967
# translating...
# decoding...
# Selecting reviews 3968 until 3999
# translating...
# decoding...
# Selecting reviews 4000 until 4031
# translating...
# decoding...
# Selecting reviews 4032 until 4063
# translating...
# decoding...
# Selecting reviews 4064 until 4095
# translating...
# decoding...
# Selecting reviews 4096 until 4127
# translating...
# decoding...
# Selecting reviews 4128 until 4159
# translating...
# decoding...
# Selecting reviews 4160 until 4191
# translating...
# decoding...
# Selecting reviews 4192 until 4223
# translating...
# decoding...
# Selecting reviews 4224 until 4255
# translating...
# decoding...
# Selecting reviews 4256 until 4287
# translating...
# decoding...
# Selecting reviews 4288 until 4319
# translating...
# decoding...
# Selecting reviews 4320 until 4351
# translating...
# decoding...
# Selecting reviews 4352 until 4383
# translating...
# decoding...
# Selecting reviews 4384 until 4415
# translating...
# decoding...
# Selecting reviews 4416 until 4447
# translating...
# decoding...
# Selecting reviews 4448 until 4479
# translating...
# decoding...
# Selecting reviews 4480 until 4511
# translating...
# decoding...
# Selecting reviews 4512 until 4543
# translating...
# decoding...
# Selecting reviews 4544 until 4575
# translating...
# decoding...
# Selecting reviews 4576 until 4607
# translating...
# decoding...
# Selecting reviews 4608 until 4639
# translating...
# decoding...
# Selecting reviews 4640 until 4671
# translating...
# decoding...
# Selecting reviews 4672 until 4703
# translating...
# decoding...
# Selecting reviews 4704 until 4735
# translating...
# decoding...
# Selecting reviews 4736 until 4767
# translating...
# decoding...
# Selecting reviews 4768 until 4799
# translating...
# decoding...
# Selecting reviews 4800 until 4831
# translating...
# decoding...
# Selecting reviews 4832 until 4863
# translating...
# decoding...
# Selecting reviews 4864 until 4895
# translating...
# decoding...
# Selecting reviews 4896 until 4927
# translating...
# decoding...
# Selecting reviews 4928 until 4959
# translating...
# decoding...
# Selecting reviews 4960 until 4991
# translating...
# decoding...
# Selecting reviews 4992 until 5023
# translating...
# decoding...
# Selecting reviews 5024 until 5055
# translating...
# decoding...
# Selecting reviews 5056 until 5087
# translating...
# decoding...
# Selecting reviews 5088 until 5119
# translating...
# decoding...
# Selecting reviews 5120 until 5151
# translating...
# decoding...
# Selecting reviews 5152 until 5183
# translating...
# decoding...
# Selecting reviews 5184 until 5215
# translating...
# decoding...
# Selecting reviews 5216 until 5247
# translating...
# decoding...
# Selecting reviews 5248 until 5279
# translating...
# decoding...
# Selecting reviews 5280 until 5311
# translating...
# decoding...
# Selecting reviews 5312 until 5343
# translating...
# decoding...
# Selecting reviews 5344 until 5375
# translating...
# decoding...
# Selecting reviews 5376 until 5407
# translating...
# decoding...
# Selecting reviews 5408 until 5439
# translating...
# decoding...
# Selecting reviews 5440 until 5471
# translating...
# decoding...
# Selecting reviews 5472 until 5503
# translating...
# decoding...
# Selecting reviews 5504 until 5535
# translating...
# decoding...
# Selecting reviews 5536 until 5567
# translating...
# decoding...
# Selecting reviews 5568 until 5599
# translating...
# decoding...
# Selecting reviews 5600 until 5631
# translating...
# decoding...
# Selecting reviews 5632 until 5663
# translating...
# decoding...
# Selecting reviews 5664 until 5695
# translating...
# decoding...
# Selecting reviews 5696 until 5727
# translating...
# decoding...
# Selecting reviews 5728 until 5759
# translating...
# decoding...
# Selecting reviews 5760 until 5791
# translating...
# decoding...
# Selecting reviews 5792 until 5824
# translating...
# decoding...

# %%
len(translated), len(df_transl)
# Out:
# (5824, 5824)

# %%
translated[:10]
# Out:
# ['@SouthwestAir a réservé la 8ème.... Sauvez-moi une issue de secours...',
#  "@united oui! Je vais envoyer un e-mail au service à la clientèle aujourd'hui.",
#  '@united Était sur NH10 sur United ticket, réacheminé vers IAD en raison de la météo à JFK. Pouvez-vous nous ramener à la maison sur United 5713 ou 3277?',
#  '@united pls suivent pour DM.',
#  "@Delta @JetBlue s'il vous plaît commencer à voler à Guyana bientôt",
#  "@Vol d'avant-vente vers #miami depuis #EWR. Voyage annuel #SOBEWFF. Maintenant.",
#  "@Delta @JetBlue The Opal Dragon book The Dragon (ALI) a tissé ses voies de meurtre des Philippines à l'Australie http://t.co/ltwhmOL1Dr",
#  '@USAirways Oui, je comprends cela. Je demande: Plus précisément, que ferez-vous des commentaires que je vous ai donnés?',
#  "@united se produit à chaque fois à l'intérieur et à la sortie de Newark.",
#  "@united J'ai envoyé un email décrivant mon expérience. J'ai hâte d'avoir un suivi pour le rendre bien."]

# %%
df_transl['text_fr'] = translated

# %%
df_transl[['text', 'text_fr']].tail()
# Out:
#                                                                                                                                        text  \
# 5819                                                                                            @SouthwestAir yes. Thank you. Oct 25-oct 31
# 5820                                @SouthwestAir thank you for your help resolving my problem Shannon ROCKS - even though Rhonda didn't !!
# 5821   @united does a good thing, keeping flight for a few for 11 peeps on late flight connecting flight. We will still destination on time
# 5822                                                            @united thanks for leaving our 3 year old in his own row flight 360 LAX-IAD
# 5823  @SouthwestAir great example of customer service this morning at MSY went to ATL. Alison and Bobbi were fantastic! Gate B8. Thank you.
#
#                                                                                                                                                                  text_fr
# 5819                                                                                                                                @SouthwestAir oui. Merci. 25 oct. 31
# 5820                                                     @SouthwestAir merci pour votre aide pour résoudre mon problème Shannon ROCKS - même si Rhonda ne l'a pas fait!!
# 5821  @united fait une bonne chose, en gardant le vol pour quelques-uns pour 11 peeps sur le vol de correspondance en retard. Nous serons toujours destination à l'heure
# 5822                                                                                   @united merci d'avoir laissé notre 3 ans dans son propre vol de ligne 360 LAX-IAD
# 5823                     @SouthwestAir excellent exemple de service à la clientèle ce matin à MOY est allé à ATL. Alison et Bobbi étaient fantastiques! Porte B8. Merci.

# %%
mname = f'Helsinki-NLP/opus-mt-{trg}-{src}'
mname
# Out:
# 'Helsinki-NLP/opus-mt-fr-en'

# %%
tokenizer = MarianTokenizer.from_pretrained(mname)
model = MarianMTModel.from_pretrained(mname)
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils.py:831: FutureWarning: Parameter max_len is deprecated and will be removed in a future release. Use model_max_length instead.
#   category=FutureWarning,

# %%
model.cuda();

# %%
bs = 32
translated_bwd = []
for i in range(int(len(df_transl)/bs)):
    if len(df_transl)-(i*bs)<=bs:
        print(f'Selecting reviews {i*bs} until {len(df_transl)}')
        src_texts=df_transl.loc[i*bs:,'text_fr']
    else: 
        print(f'Selecting reviews {i*bs} until {i*bs+bs-1}')
        src_texts=df_transl.loc[i*bs:i*bs+bs-1,'text_fr']
    batch = tokenizer.prepare_translation_batch(src_texts=src_texts)
    print('translating...')
    gen = model.generate(batch.input_ids.cuda())
    print('decoding...')
    decoded = [tokenizer.decode(g, skip_special_tokens=True) for g in gen]
    translated_bwd.extend(decoded)
# Out:
# Selecting reviews 0 until 31
# translating...
# decoding...
# Selecting reviews 32 until 63
# translating...
# decoding...
# Selecting reviews 64 until 95
# translating...
# decoding...
# Selecting reviews 96 until 127
# translating...
# decoding...
# Selecting reviews 128 until 159
# translating...
# decoding...
# Selecting reviews 160 until 191
# translating...
# decoding...
# Selecting reviews 192 until 223
# translating...
# decoding...
# Selecting reviews 224 until 255
# translating...
# decoding...
# Selecting reviews 256 until 287
# translating...
# decoding...
# Selecting reviews 288 until 319
# translating...
# decoding...
# Selecting reviews 320 until 351
# translating...
# decoding...
# Selecting reviews 352 until 383
# translating...
# decoding...
# Selecting reviews 384 until 415
# translating...
# decoding...
# Selecting reviews 416 until 447
# translating...
# decoding...
# Selecting reviews 448 until 479
# translating...
# decoding...
# Selecting reviews 480 until 511
# translating...
# decoding...
# Selecting reviews 512 until 543
# translating...
# decoding...
# Selecting reviews 544 until 575
# translating...
# decoding...
# Selecting reviews 576 until 607
# translating...
# decoding...
# Selecting reviews 608 until 639
# translating...
# decoding...
# Selecting reviews 640 until 671
# translating...
# decoding...
# Selecting reviews 672 until 703
# translating...
# decoding...
# Selecting reviews 704 until 735
# translating...
# decoding...
# Selecting reviews 736 until 767
# translating...
# decoding...
# Selecting reviews 768 until 799
# translating...
# decoding...
# Selecting reviews 800 until 831
# translating...
# decoding...
# Selecting reviews 832 until 863
# translating...
# decoding...
# Selecting reviews 864 until 895
# translating...
# decoding...
# Selecting reviews 896 until 927
# translating...
# decoding...
# Selecting reviews 928 until 959
# translating...
# decoding...
# Selecting reviews 960 until 991
# translating...
# decoding...
# Selecting reviews 992 until 1023
# translating...
# decoding...
# Selecting reviews 1024 until 1055
# translating...
# decoding...
# Selecting reviews 1056 until 1087
# translating...
# decoding...
# Selecting reviews 1088 until 1119
# translating...
# decoding...
# Selecting reviews 1120 until 1151
# translating...
# decoding...
# Selecting reviews 1152 until 1183
# translating...
# decoding...
# Selecting reviews 1184 until 1215
# translating...
# decoding...
# Selecting reviews 1216 until 1247
# translating...
# decoding...
# Selecting reviews 1248 until 1279
# translating...
# decoding...
# Selecting reviews 1280 until 1311
# translating...
# decoding...
# Selecting reviews 1312 until 1343
# translating...
# decoding...
# Selecting reviews 1344 until 1375
# translating...
# decoding...
# Selecting reviews 1376 until 1407
# translating...
# decoding...
# Selecting reviews 1408 until 1439
# translating...
# decoding...
# Selecting reviews 1440 until 1471
# translating...
# decoding...
# Selecting reviews 1472 until 1503
# translating...
# decoding...
# Selecting reviews 1504 until 1535
# translating...
# decoding...
# Selecting reviews 1536 until 1567
# translating...
# decoding...
# Selecting reviews 1568 until 1599
# translating...
# decoding...
# Selecting reviews 1600 until 1631
# translating...
# decoding...
# Selecting reviews 1632 until 1663
# translating...
# decoding...
# Selecting reviews 1664 until 1695
# translating...
# decoding...
# Selecting reviews 1696 until 1727
# translating...
# decoding...
# Selecting reviews 1728 until 1759
# translating...
# decoding...
# Selecting reviews 1760 until 1791
# translating...
# decoding...
# Selecting reviews 1792 until 1823
# translating...
# decoding...
# Selecting reviews 1824 until 1855
# translating...
# decoding...
# Selecting reviews 1856 until 1887
# translating...
# decoding...
# Selecting reviews 1888 until 1919
# translating...
# decoding...
# Selecting reviews 1920 until 1951
# translating...
# decoding...
# Selecting reviews 1952 until 1983
# translating...
# decoding...
# Selecting reviews 1984 until 2015
# translating...
# decoding...
# Selecting reviews 2016 until 2047
# translating...
# decoding...
# Selecting reviews 2048 until 2079
# translating...
# decoding...
# Selecting reviews 2080 until 2111
# translating...
# decoding...
# Selecting reviews 2112 until 2143
# translating...
# decoding...
# Selecting reviews 2144 until 2175
# translating...
# decoding...
# Selecting reviews 2176 until 2207
# translating...
# decoding...
# Selecting reviews 2208 until 2239
# translating...
# decoding...
# Selecting reviews 2240 until 2271
# translating...
# decoding...
# Selecting reviews 2272 until 2303
# translating...
# decoding...
# Selecting reviews 2304 until 2335
# translating...
# decoding...
# Selecting reviews 2336 until 2367
# translating...
# decoding...
# Selecting reviews 2368 until 2399
# translating...
# decoding...
# Selecting reviews 2400 until 2431
# translating...
# decoding...
# Selecting reviews 2432 until 2463
# translating...
# decoding...
# Selecting reviews 2464 until 2495
# translating...
# decoding...
# Selecting reviews 2496 until 2527
# translating...
# decoding...
# Selecting reviews 2528 until 2559
# translating...
# decoding...
# Selecting reviews 2560 until 2591
# translating...
# decoding...
# Selecting reviews 2592 until 2623
# translating...
# decoding...
# Selecting reviews 2624 until 2655
# translating...
# decoding...
# Selecting reviews 2656 until 2687
# translating...
# decoding...
# Selecting reviews 2688 until 2719
# translating...
# decoding...
# Selecting reviews 2720 until 2751
# translating...
# decoding...
# Selecting reviews 2752 until 2783
# translating...
# decoding...
# Selecting reviews 2784 until 2815
# translating...
# decoding...
# Selecting reviews 2816 until 2847
# translating...
# decoding...
# Selecting reviews 2848 until 2879
# translating...
# decoding...
# Selecting reviews 2880 until 2911
# translating...
# decoding...
# Selecting reviews 2912 until 2943
# translating...
# decoding...
# Selecting reviews 2944 until 2975
# translating...
# decoding...
# Selecting reviews 2976 until 3007
# translating...
# decoding...
# Selecting reviews 3008 until 3039
# translating...
# decoding...
# Selecting reviews 3040 until 3071
# translating...
# decoding...
# Selecting reviews 3072 until 3103
# translating...
# decoding...
# Selecting reviews 3104 until 3135
# translating...
# decoding...
# Selecting reviews 3136 until 3167
# translating...
# decoding...
# Selecting reviews 3168 until 3199
# translating...
# decoding...
# Selecting reviews 3200 until 3231
# translating...
# decoding...
# Selecting reviews 3232 until 3263
# translating...
# decoding...
# Selecting reviews 3264 until 3295
# translating...
# decoding...
# Selecting reviews 3296 until 3327
# translating...
# decoding...
# Selecting reviews 3328 until 3359
# translating...
# decoding...
# Selecting reviews 3360 until 3391
# translating...
# decoding...
# Selecting reviews 3392 until 3423
# translating...
# decoding...
# Selecting reviews 3424 until 3455
# translating...
# decoding...
# Selecting reviews 3456 until 3487
# translating...
# decoding...
# Selecting reviews 3488 until 3519
# translating...
# decoding...
# Selecting reviews 3520 until 3551
# translating...
# decoding...
# Selecting reviews 3552 until 3583
# translating...
# decoding...
# Selecting reviews 3584 until 3615
# translating...
# decoding...
# Selecting reviews 3616 until 3647
# translating...
# decoding...
# Selecting reviews 3648 until 3679
# translating...
# decoding...
# Selecting reviews 3680 until 3711
# translating...
# decoding...
# Selecting reviews 3712 until 3743
# translating...
# decoding...
# Selecting reviews 3744 until 3775
# translating...
# decoding...
# Selecting reviews 3776 until 3807
# translating...
# decoding...
# Selecting reviews 3808 until 3839
# translating...
# decoding...
# Selecting reviews 3840 until 3871
# translating...
# decoding...
# Selecting reviews 3872 until 3903
# translating...
# decoding...
# Selecting reviews 3904 until 3935
# translating...
# decoding...
# Selecting reviews 3936 until 3967
# translating...
# decoding...
# Selecting reviews 3968 until 3999
# translating...
# decoding...
# Selecting reviews 4000 until 4031
# translating...
# decoding...
# Selecting reviews 4032 until 4063
# translating...
# decoding...
# Selecting reviews 4064 until 4095
# translating...
# decoding...
# Selecting reviews 4096 until 4127
# translating...
# decoding...
# Selecting reviews 4128 until 4159
# translating...
# decoding...
# Selecting reviews 4160 until 4191
# translating...
# decoding...
# Selecting reviews 4192 until 4223
# translating...
# decoding...
# Selecting reviews 4224 until 4255
# translating...
# decoding...
# Selecting reviews 4256 until 4287
# translating...
# decoding...
# Selecting reviews 4288 until 4319
# translating...
# decoding...
# Selecting reviews 4320 until 4351
# translating...
# decoding...
# Selecting reviews 4352 until 4383
# translating...
# decoding...
# Selecting reviews 4384 until 4415
# translating...
# decoding...
# Selecting reviews 4416 until 4447
# translating...
# decoding...
# Selecting reviews 4448 until 4479
# translating...
# decoding...
# Selecting reviews 4480 until 4511
# translating...
# decoding...
# Selecting reviews 4512 until 4543
# translating...
# decoding...
# Selecting reviews 4544 until 4575
# translating...
# decoding...
# Selecting reviews 4576 until 4607
# translating...
# decoding...
# Selecting reviews 4608 until 4639
# translating...
# decoding...
# Selecting reviews 4640 until 4671
# translating...
# decoding...
# Selecting reviews 4672 until 4703
# translating...
# decoding...
# Selecting reviews 4704 until 4735
# translating...
# decoding...
# Selecting reviews 4736 until 4767
# translating...
# decoding...
# Selecting reviews 4768 until 4799
# translating...
# decoding...
# Selecting reviews 4800 until 4831
# translating...
# decoding...
# Selecting reviews 4832 until 4863
# translating...
# decoding...
# Selecting reviews 4864 until 4895
# translating...
# decoding...
# Selecting reviews 4896 until 4927
# translating...
# decoding...
# Selecting reviews 4928 until 4959
# translating...
# decoding...
# Selecting reviews 4960 until 4991
# translating...
# decoding...
# Selecting reviews 4992 until 5023
# translating...
# decoding...
# Selecting reviews 5024 until 5055
# translating...
# decoding...
# Selecting reviews 5056 until 5087
# translating...
# decoding...
# Selecting reviews 5088 until 5119
# translating...
# decoding...
# Selecting reviews 5120 until 5151
# translating...
# decoding...
# Selecting reviews 5152 until 5183
# translating...
# decoding...
# Selecting reviews 5184 until 5215
# translating...
# decoding...
# Selecting reviews 5216 until 5247
# translating...
# decoding...
# Selecting reviews 5248 until 5279
# translating...
# decoding...
# Selecting reviews 5280 until 5311
# translating...
# decoding...
# Selecting reviews 5312 until 5343
# translating...
# decoding...
# Selecting reviews 5344 until 5375
# translating...
# decoding...
# Selecting reviews 5376 until 5407
# translating...
# decoding...
# Selecting reviews 5408 until 5439
# translating...
# decoding...
# Selecting reviews 5440 until 5471
# translating...
# decoding...
# Selecting reviews 5472 until 5503
# translating...
# decoding...
# Selecting reviews 5504 until 5535
# translating...
# decoding...
# Selecting reviews 5536 until 5567
# translating...
# decoding...
# Selecting reviews 5568 until 5599
# translating...
# decoding...
# Selecting reviews 5600 until 5631
# translating...
# decoding...
# Selecting reviews 5632 until 5663
# translating...
# decoding...
# Selecting reviews 5664 until 5695
# translating...
# decoding...
# Selecting reviews 5696 until 5727
# translating...
# decoding...
# Selecting reviews 5728 until 5759
# translating...
# decoding...
# Selecting reviews 5760 until 5791
# translating...
# decoding...
# Selecting reviews 5792 until 5824
# translating...
# decoding...

# %%
len(df_transl), len(translated_bwd)
# Out:
# (5824, 5824)

# %%
df_transl['text'] = translated_bwd

# %%
df_transl['translated'] = True

# %%
df_new = pd.concat([df, df_transl]).reset_index(drop=True)

# %%
len(df_new)
# Out:
# 35104

# %%
Counter(df_new[df_new.is_valid==False].airline_sentiment)
# Out:
# Counter({'negative': 14624, 'neutral': 7312, 'positive': 7312})

# %%
df_new.to_csv('Tweets_final_aug.csv', index=False)
